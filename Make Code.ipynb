# %%
for x in range(33):



    print ("            elif ((c ==" , x , " and")


    t = x

    
    while (t > 0):
     
  

        print ("            cust_data.iloc[r,c-" , t , "] == 0 and")
        
        t = t-1     
    
    print ("            cust_data.iloc[r,c] == 0 and")
    print ("            cust_data.iloc[r,c+1] > 0 and")
    print ("            cust_data.iloc[r,c+2] > 0 and")
    print ("            cust_data.iloc[r,c+3] > 0 and")
    print ("            cust_data.iloc[r,c+4] > 0 )):")
    print ("#")
    print ("                cust_data.iat[r,0]=cust_data.iat[r,c]")
    print ("                cust_data.iat[r,1]=cust_data.iat[r,c+1]")
    print ("                cust_data.iat[r,2]=cust_data.iat[r,c+2]")
    print ("                cust_data.iat[r,3]=cust_data.iat[r,c+3]")
    print ("                cust_data.iat[r,4]=cust_data.iat[r,c+4]")
    print ("# ")
    print ("                print(r,c)")
    print ("##")
# Out:
#             elif ((c == 0  and
#             cust_data.iloc[r,c] == 0 and
#             cust_data.iloc[r,c+1] > 0 and
#             cust_data.iloc[r,c+2] > 0 and
#             cust_data.iloc[r,c+3] > 0 and
#             cust_data.iloc[r,c+4] > 0 )):
# #
#                 cust_data.iat[r,0]=cust_data.iat[r,c]
#                 cust_data.iat[r,1]=cust_data.iat[r,c+1]
#                 cust_data.iat[r,2]=cust_data.iat[r,c+2]
#                 cust_data.iat[r,3]=cust_data.iat[r,c+3]
#                 cust_data.iat[r,4]=cust_data.iat[r,c+4]
# #
#                 print(r,c)
# ##
#             elif ((c == 1  and
#             cust_data.iloc[r,c- 1 ] == 0 and
#             cust_data.iloc[r,c] == 0 and
#             cust_data.iloc[r,c+1] > 0 and
#             cust_data.iloc[r,c+2] > 0 and
#             cust_data.iloc[r,c+3] > 0 and
#             cust_data.iloc[r,c+4] > 0 )):
# #
#                 cust_data.iat[r,0]=cust_data.iat[r,c]
#                 cust_data.iat[r,1]=cust_data.iat[r,c+1]
# ...
