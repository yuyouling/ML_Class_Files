# %%
import pandas as pd

cust_data = pd.read_csv("Holt Spend V6.csv")
cust_data.head(10)

# %% [markdown]
# # Stage 1
#
# ### Drop any row which has a negative value
#
# ### We are only interested where P1 = 0 and P2 & P3 & P4 & P5 & P6 > 0
#
# ### Search along the rows and find where we have a pattern of a period = 0 followed by 5 periods > 0
# ### In that case move the data string into the period starting P1

# %%
cust_data.describe()

# %% [markdown]
# ### Move the Cuno to the index - solves a problem with a string in the df

# %%
#cust_data = cust_data.drop('Cuno',axis=1)

cust_data.set_index('Cuno',inplace=True)

cust_data.head(10)

# %% [markdown]
# ### Drop any row which has a negative value

# %%
cust_data = cust_data[(cust_data > -.1).all(axis=1)]

# %% [markdown]
# ### Take a look at the data.

# %%
cust_data.describe()

# %%
cust_data.shape

# %% [markdown]
# ### Get a count or the rows and columns

# %%
Rows, Cols = cust_data.shape

print(Rows, Cols )

# %% [markdown]
# ### Search along every row looking for a data pattern of
# ### The current cell being = 0 and the next 4 cells > 0 and all previous cells in that current row = 0
# ### When you find that pattern move those cells to start in position 0
# ### This indicates a customer did not do any business last month but did in the four months prior
# ### Moving to position 0 means that the target is always in position 0

# %%
for r in range(Rows+0):

    for c in range (Cols+0):
      
        if c <= 33:
      
            if ((c == 0 and
            cust_data.iloc[r,c] == 0 and
            cust_data.iloc[r,c+1] > 0 and 
            cust_data.iloc[r,c+2] > 0 and      
            cust_data.iloc[r,c+3] > 0 and
            cust_data.iloc[r,c+4] > 0 )):
        
               x=1    
    
 
            elif ((c ==1 and
            cust_data.iloc[r,c-1] == 0 and
            cust_data.iloc[r,c] == 0 and
            cust_data.iloc[r,c+1] > 0 and
            cust_data.iloc[r,c+2] > 0 and
            cust_data.iloc[r,c+3] > 0 and
            cust_data.iloc[r,c+4] > 0 )):
#
                cust_data.iat[r,0]=cust_data.iat[r,c]
                cust_data.iat[r,1]=cust_data.iat[r,c+1]
                cust_data.iat[r,2]=cust_data.iat[r,c+2]
                cust_data.iat[r,3]=cust_data.iat[r,c+3]
                cust_data.iat[r,4]=cust_data.iat[r,c+4]
# 
                # print ("True",r,c)
##
            elif ((c ==2 and
            cust_data.iloc[r,c-2] == 0 and
            cust_data.iloc[r,c-1] == 0 and
            cust_data.iloc[r,c] == 0 and
            cust_data.iloc[r,c+1] > 0 and
            cust_data.iloc[r,c+2] > 0 and
            cust_data.iloc[r,c+3] > 0 and
            cust_data.iloc[r,c+4] > 0 )):
#
                cust_data.iat[r,0]=cust_data.iat[r,c]
                cust_data.iat[r,1]=cust_data.iat[r,c+1]
                cust_data.iat[r,2]=cust_data.iat[r,c+2]
                cust_data.iat[r,3]=cust_data.iat[r,c+3]
                cust_data.iat[r,4]=cust_data.iat[r,c+4]
# 
                # print ("True",r,c)
##
            elif ((c ==3 and
            cust_data.iloc[r,c-3] == 0 and
            cust_data.iloc[r,c-2] == 0 and
            cust_data.iloc[r,c-1] == 0 and
            cust_data.iloc[r,c] == 0 and
            cust_data.iloc[r,c+1] > 0 and
            cust_data.iloc[r,c+2] > 0 and
            cust_data.iloc[r,c+3] > 0 and
            cust_data.iloc[r,c+4] > 0 )):
#
                cust_data.iat[r,0]=cust_data.iat[r,c]
                cust_data.iat[r,1]=cust_data.iat[r,c+1]
                cust_data.iat[r,2]=cust_data.iat[r,c+2]
                cust_data.iat[r,3]=cust_data.iat[r,c+3]
                cust_data.iat[r,4]=cust_data.iat[r,c+4]
# 
                # print ("True",r,c)
##
            elif ((c ==4 and
            cust_data.iloc[r,c-4] == 0 and
            cust_data.iloc[r,c-3] == 0 and
            cust_data.iloc[r,c-2] == 0 and
            cust_data.iloc[r,c-1] == 0 and
            cust_data.iloc[r,c] == 0 and
            cust_data.iloc[r,c+1] > 0 and
            cust_data.iloc[r,c+2] > 0 and
            cust_data.iloc[r,c+3] > 0 and
            cust_data.iloc[r,c+4] > 0 )):
#
                cust_data.iat[r,0]=cust_data.iat[r,c]
                cust_data.iat[r,1]=cust_data.iat[r,c+1]
                cust_data.iat[r,2]=cust_data.iat[r,c+2]
                cust_data.iat[r,3]=cust_data.iat[r,c+3]
                cust_data.iat[r,4]=cust_data.iat[r,c+4]
# 
                # print ("True",r,c)
##
            elif ((c ==5 and
            cust_data.iloc[r,c-5] == 0 and
            cust_data.iloc[r,c-4] == 0 and
            cust_data.iloc[r,c-3] == 0 and
            cust_data.iloc[r,c-2] == 0 and
            cust_data.iloc[r,c-1] == 0 and
            cust_data.iloc[r,c] == 0 and
            cust_data.iloc[r,c+1] > 0 and
            cust_data.iloc[r,c+2] > 0 and
            cust_data.iloc[r,c+3] > 0 and
            cust_data.iloc[r,c+4] > 0 )):
#
                cust_data.iat[r,0]=cust_data.iat[r,c]
                cust_data.iat[r,1]=cust_data.iat[r,c+1]
                cust_data.iat[r,2]=cust_data.iat[r,c+2]
                cust_data.iat[r,3]=cust_data.iat[r,c+3]
                cust_data.iat[r,4]=cust_data.iat[r,c+4]
# 
                # print ("True",r,c)
##
            elif ((c ==6 and
            cust_data.iloc[r,c-6] == 0 and
            cust_data.iloc[r,c-5] == 0 and
            cust_data.iloc[r,c-4] == 0 and
            cust_data.iloc[r,c-3] == 0 and
            cust_data.iloc[r,c-2] == 0 and
            cust_data.iloc[r,c-1] == 0 and
            cust_data.iloc[r,c] == 0 and
            cust_data.iloc[r,c+1] > 0 and
            cust_data.iloc[r,c+2] > 0 and
            cust_data.iloc[r,c+3] > 0 and
            cust_data.iloc[r,c+4] > 0 )):
#
                cust_data.iat[r,0]=cust_data.iat[r,c]
                cust_data.iat[r,1]=cust_data.iat[r,c+1]
                cust_data.iat[r,2]=cust_data.iat[r,c+2]
                cust_data.iat[r,3]=cust_data.iat[r,c+3]
                cust_data.iat[r,4]=cust_data.iat[r,c+4]
# 
                # print ("True",r,c)
##
            elif ((c ==7 and
            cust_data.iloc[r,c-7] == 0 and
            cust_data.iloc[r,c-6] == 0 and
            cust_data.iloc[r,c-5] == 0 and
            cust_data.iloc[r,c-4] == 0 and
            cust_data.iloc[r,c-3] == 0 and
            cust_data.iloc[r,c-2] == 0 and
            cust_data.iloc[r,c-1] == 0 and
            cust_data.iloc[r,c] == 0 and
            cust_data.iloc[r,c+1] > 0 and
            cust_data.iloc[r,c+2] > 0 and
            cust_data.iloc[r,c+3] > 0 and
            cust_data.iloc[r,c+4] > 0 )):
#
                cust_data.iat[r,0]=cust_data.iat[r,c]
                cust_data.iat[r,1]=cust_data.iat[r,c+1]
                cust_data.iat[r,2]=cust_data.iat[r,c+2]
                cust_data.iat[r,3]=cust_data.iat[r,c+3]
                cust_data.iat[r,4]=cust_data.iat[r,c+4]
# 
                # print ("True",r,c)
##
            elif ((c ==8 and
            cust_data.iloc[r,c-8] == 0 and
            cust_data.iloc[r,c-7] == 0 and
            cust_data.iloc[r,c-6] == 0 and
            cust_data.iloc[r,c-5] == 0 and
            cust_data.iloc[r,c-4] == 0 and
            cust_data.iloc[r,c-3] == 0 and
            cust_data.iloc[r,c-2] == 0 and
            cust_data.iloc[r,c-1] == 0 and
            cust_data.iloc[r,c] == 0 and
            cust_data.iloc[r,c+1] > 0 and
            cust_data.iloc[r,c+2] > 0 and
            cust_data.iloc[r,c+3] > 0 and
            cust_data.iloc[r,c+4] > 0 )):
#
                cust_data.iat[r,0]=cust_data.iat[r,c]
                cust_data.iat[r,1]=cust_data.iat[r,c+1]
                cust_data.iat[r,2]=cust_data.iat[r,c+2]
                cust_data.iat[r,3]=cust_data.iat[r,c+3]
                cust_data.iat[r,4]=cust_data.iat[r,c+4]
# 
                # print ("True",r,c)
##
            elif ((c ==9 and
            cust_data.iloc[r,c-9] == 0 and
            cust_data.iloc[r,c-8] == 0 and
            cust_data.iloc[r,c-7] == 0 and
            cust_data.iloc[r,c-6] == 0 and
            cust_data.iloc[r,c-5] == 0 and
            cust_data.iloc[r,c-4] == 0 and
            cust_data.iloc[r,c-3] == 0 and
            cust_data.iloc[r,c-2] == 0 and
            cust_data.iloc[r,c-1] == 0 and
            cust_data.iloc[r,c] == 0 and
            cust_data.iloc[r,c+1] > 0 and
            cust_data.iloc[r,c+2] > 0 and
            cust_data.iloc[r,c+3] > 0 and
            cust_data.iloc[r,c+4] > 0 )):
#
                cust_data.iat[r,0]=cust_data.iat[r,c]
                cust_data.iat[r,1]=cust_data.iat[r,c+1]
                cust_data.iat[r,2]=cust_data.iat[r,c+2]
                cust_data.iat[r,3]=cust_data.iat[r,c+3]
                cust_data.iat[r,4]=cust_data.iat[r,c+4]
# 
                # print ("True",r,c)
##
            elif ((c ==10 and
            cust_data.iloc[r,c-10] == 0 and
            cust_data.iloc[r,c-9] == 0 and
            cust_data.iloc[r,c-8] == 0 and
            cust_data.iloc[r,c-7] == 0 and
            cust_data.iloc[r,c-6] == 0 and
            cust_data.iloc[r,c-5] == 0 and
            cust_data.iloc[r,c-4] == 0 and
            cust_data.iloc[r,c-3] == 0 and
            cust_data.iloc[r,c-2] == 0 and
            cust_data.iloc[r,c-1] == 0 and
            cust_data.iloc[r,c] == 0 and
            cust_data.iloc[r,c+1] > 0 and
            cust_data.iloc[r,c+2] > 0 and
            cust_data.iloc[r,c+3] > 0 and
            cust_data.iloc[r,c+4] > 0 )):
#
                cust_data.iat[r,0]=cust_data.iat[r,c]
                cust_data.iat[r,1]=cust_data.iat[r,c+1]
                cust_data.iat[r,2]=cust_data.iat[r,c+2]
                cust_data.iat[r,3]=cust_data.iat[r,c+3]
                cust_data.iat[r,4]=cust_data.iat[r,c+4]
# 
                # print ("True",r,c)
##
            elif ((c ==11 and
            cust_data.iloc[r,c-11] == 0 and
            cust_data.iloc[r,c-10] == 0 and
            cust_data.iloc[r,c-9] == 0 and
            cust_data.iloc[r,c-8] == 0 and
            cust_data.iloc[r,c-7] == 0 and
            cust_data.iloc[r,c-6] == 0 and
            cust_data.iloc[r,c-5] == 0 and
            cust_data.iloc[r,c-4] == 0 and
            cust_data.iloc[r,c-3] == 0 and
            cust_data.iloc[r,c-2] == 0 and
            cust_data.iloc[r,c-1] == 0 and
            cust_data.iloc[r,c] == 0 and
            cust_data.iloc[r,c+1] > 0 and
            cust_data.iloc[r,c+2] > 0 and
            cust_data.iloc[r,c+3] > 0 and
            cust_data.iloc[r,c+4] > 0 )):
#
                cust_data.iat[r,0]=cust_data.iat[r,c]
                cust_data.iat[r,1]=cust_data.iat[r,c+1]
                cust_data.iat[r,2]=cust_data.iat[r,c+2]
                cust_data.iat[r,3]=cust_data.iat[r,c+3]
                cust_data.iat[r,4]=cust_data.iat[r,c+4]
# 
                # print ("True",r,c)
##
            elif ((c ==12 and
            cust_data.iloc[r,c-12] == 0 and
            cust_data.iloc[r,c-11] == 0 and
            cust_data.iloc[r,c-10] == 0 and
            cust_data.iloc[r,c-9] == 0 and
            cust_data.iloc[r,c-8] == 0 and
            cust_data.iloc[r,c-7] == 0 and
            cust_data.iloc[r,c-6] == 0 and
            cust_data.iloc[r,c-5] == 0 and
            cust_data.iloc[r,c-4] == 0 and
            cust_data.iloc[r,c-3] == 0 and
            cust_data.iloc[r,c-2] == 0 and
            cust_data.iloc[r,c-1] == 0 and
            cust_data.iloc[r,c] == 0 and
            cust_data.iloc[r,c+1] > 0 and
            cust_data.iloc[r,c+2] > 0 and
            cust_data.iloc[r,c+3] > 0 and
            cust_data.iloc[r,c+4] > 0 )):
#
                cust_data.iat[r,0]=cust_data.iat[r,c]
                cust_data.iat[r,1]=cust_data.iat[r,c+1]
                cust_data.iat[r,2]=cust_data.iat[r,c+2]
                cust_data.iat[r,3]=cust_data.iat[r,c+3]
                cust_data.iat[r,4]=cust_data.iat[r,c+4]
# 
                # print ("True",r,c)
##
            elif ((c ==13 and
            cust_data.iloc[r,c-13] == 0 and
            cust_data.iloc[r,c-12] == 0 and
            cust_data.iloc[r,c-11] == 0 and
            cust_data.iloc[r,c-10] == 0 and
            cust_data.iloc[r,c-9] == 0 and
            cust_data.iloc[r,c-8] == 0 and
            cust_data.iloc[r,c-7] == 0 and
            cust_data.iloc[r,c-6] == 0 and
            cust_data.iloc[r,c-5] == 0 and
            cust_data.iloc[r,c-4] == 0 and
            cust_data.iloc[r,c-3] == 0 and
            cust_data.iloc[r,c-2] == 0 and
            cust_data.iloc[r,c-1] == 0 and
            cust_data.iloc[r,c] == 0 and
            cust_data.iloc[r,c+1] > 0 and
            cust_data.iloc[r,c+2] > 0 and
            cust_data.iloc[r,c+3] > 0 and
            cust_data.iloc[r,c+4] > 0 )):
#
                cust_data.iat[r,0]=cust_data.iat[r,c]
                cust_data.iat[r,1]=cust_data.iat[r,c+1]
                cust_data.iat[r,2]=cust_data.iat[r,c+2]
                cust_data.iat[r,3]=cust_data.iat[r,c+3]
                cust_data.iat[r,4]=cust_data.iat[r,c+4]
# 
                # print ("True",r,c)
##
            elif ((c ==14 and
            cust_data.iloc[r,c-14] == 0 and
            cust_data.iloc[r,c-13] == 0 and
            cust_data.iloc[r,c-12] == 0 and
            cust_data.iloc[r,c-11] == 0 and
            cust_data.iloc[r,c-10] == 0 and
            cust_data.iloc[r,c-9] == 0 and
            cust_data.iloc[r,c-8] == 0 and
            cust_data.iloc[r,c-7] == 0 and
            cust_data.iloc[r,c-6] == 0 and
            cust_data.iloc[r,c-5] == 0 and
            cust_data.iloc[r,c-4] == 0 and
            cust_data.iloc[r,c-3] == 0 and
            cust_data.iloc[r,c-2] == 0 and
            cust_data.iloc[r,c-1] == 0 and
            cust_data.iloc[r,c] == 0 and
            cust_data.iloc[r,c+1] > 0 and
            cust_data.iloc[r,c+2] > 0 and
            cust_data.iloc[r,c+3] > 0 and
            cust_data.iloc[r,c+4] > 0 )):
#
                cust_data.iat[r,0]=cust_data.iat[r,c]
                cust_data.iat[r,1]=cust_data.iat[r,c+1]
                cust_data.iat[r,2]=cust_data.iat[r,c+2]
                cust_data.iat[r,3]=cust_data.iat[r,c+3]
                cust_data.iat[r,4]=cust_data.iat[r,c+4]
# 
                # print ("True",r,c)
##
            elif ((c ==15 and
            cust_data.iloc[r,c-15] == 0 and
            cust_data.iloc[r,c-14] == 0 and
            cust_data.iloc[r,c-13] == 0 and
            cust_data.iloc[r,c-12] == 0 and
            cust_data.iloc[r,c-11] == 0 and
            cust_data.iloc[r,c-10] == 0 and
            cust_data.iloc[r,c-9] == 0 and
            cust_data.iloc[r,c-8] == 0 and
            cust_data.iloc[r,c-7] == 0 and
            cust_data.iloc[r,c-6] == 0 and
            cust_data.iloc[r,c-5] == 0 and
            cust_data.iloc[r,c-4] == 0 and
            cust_data.iloc[r,c-3] == 0 and
            cust_data.iloc[r,c-2] == 0 and
            cust_data.iloc[r,c-1] == 0 and
            cust_data.iloc[r,c] == 0 and
            cust_data.iloc[r,c+1] > 0 and
            cust_data.iloc[r,c+2] > 0 and
            cust_data.iloc[r,c+3] > 0 and
            cust_data.iloc[r,c+4] > 0 )):
#
                cust_data.iat[r,0]=cust_data.iat[r,c]
                cust_data.iat[r,1]=cust_data.iat[r,c+1]
                cust_data.iat[r,2]=cust_data.iat[r,c+2]
                cust_data.iat[r,3]=cust_data.iat[r,c+3]
                cust_data.iat[r,4]=cust_data.iat[r,c+4]
# 
                # print ("True",r,c)
##
            elif ((c ==16 and
            cust_data.iloc[r,c-16] == 0 and
            cust_data.iloc[r,c-15] == 0 and
            cust_data.iloc[r,c-14] == 0 and
            cust_data.iloc[r,c-13] == 0 and
            cust_data.iloc[r,c-12] == 0 and
            cust_data.iloc[r,c-11] == 0 and
            cust_data.iloc[r,c-10] == 0 and
            cust_data.iloc[r,c-9] == 0 and
            cust_data.iloc[r,c-8] == 0 and
            cust_data.iloc[r,c-7] == 0 and
            cust_data.iloc[r,c-6] == 0 and
            cust_data.iloc[r,c-5] == 0 and
            cust_data.iloc[r,c-4] == 0 and
            cust_data.iloc[r,c-3] == 0 and
            cust_data.iloc[r,c-2] == 0 and
            cust_data.iloc[r,c-1] == 0 and
            cust_data.iloc[r,c] == 0 and
            cust_data.iloc[r,c+1] > 0 and
            cust_data.iloc[r,c+2] > 0 and
            cust_data.iloc[r,c+3] > 0 and
            cust_data.iloc[r,c+4] > 0 )):
#
                cust_data.iat[r,0]=cust_data.iat[r,c]
                cust_data.iat[r,1]=cust_data.iat[r,c+1]
                cust_data.iat[r,2]=cust_data.iat[r,c+2]
                cust_data.iat[r,3]=cust_data.iat[r,c+3]
                cust_data.iat[r,4]=cust_data.iat[r,c+4]
# 
                # print ("True",r,c)
##
            elif ((c ==17 and
            cust_data.iloc[r,c-17] == 0 and
            cust_data.iloc[r,c-16] == 0 and
            cust_data.iloc[r,c-15] == 0 and
            cust_data.iloc[r,c-14] == 0 and
            cust_data.iloc[r,c-13] == 0 and
            cust_data.iloc[r,c-12] == 0 and
            cust_data.iloc[r,c-11] == 0 and
            cust_data.iloc[r,c-10] == 0 and
            cust_data.iloc[r,c-9] == 0 and
            cust_data.iloc[r,c-8] == 0 and
            cust_data.iloc[r,c-7] == 0 and
            cust_data.iloc[r,c-6] == 0 and
            cust_data.iloc[r,c-5] == 0 and
            cust_data.iloc[r,c-4] == 0 and
            cust_data.iloc[r,c-3] == 0 and
            cust_data.iloc[r,c-2] == 0 and
            cust_data.iloc[r,c-1] == 0 and
            cust_data.iloc[r,c] == 0 and
            cust_data.iloc[r,c+1] > 0 and
            cust_data.iloc[r,c+2] > 0 and
            cust_data.iloc[r,c+3] > 0 and
            cust_data.iloc[r,c+4] > 0 )):
#
                cust_data.iat[r,0]=cust_data.iat[r,c]
                cust_data.iat[r,1]=cust_data.iat[r,c+1]
                cust_data.iat[r,2]=cust_data.iat[r,c+2]
                cust_data.iat[r,3]=cust_data.iat[r,c+3]
                cust_data.iat[r,4]=cust_data.iat[r,c+4]
# 
                # print ("True",r,c)
##
            elif ((c ==18 and
            cust_data.iloc[r,c-18] == 0 and
            cust_data.iloc[r,c-17] == 0 and
            cust_data.iloc[r,c-16] == 0 and
            cust_data.iloc[r,c-15] == 0 and
            cust_data.iloc[r,c-14] == 0 and
            cust_data.iloc[r,c-13] == 0 and
            cust_data.iloc[r,c-12] == 0 and
            cust_data.iloc[r,c-11] == 0 and
            cust_data.iloc[r,c-10] == 0 and
            cust_data.iloc[r,c-9] == 0 and
            cust_data.iloc[r,c-8] == 0 and
            cust_data.iloc[r,c-7] == 0 and
            cust_data.iloc[r,c-6] == 0 and
            cust_data.iloc[r,c-5] == 0 and
            cust_data.iloc[r,c-4] == 0 and
            cust_data.iloc[r,c-3] == 0 and
            cust_data.iloc[r,c-2] == 0 and
            cust_data.iloc[r,c-1] == 0 and
            cust_data.iloc[r,c] == 0 and
            cust_data.iloc[r,c+1] > 0 and
            cust_data.iloc[r,c+2] > 0 and
            cust_data.iloc[r,c+3] > 0 and
            cust_data.iloc[r,c+4] > 0 )):
#
                cust_data.iat[r,0]=cust_data.iat[r,c]
                cust_data.iat[r,1]=cust_data.iat[r,c+1]
                cust_data.iat[r,2]=cust_data.iat[r,c+2]
                cust_data.iat[r,3]=cust_data.iat[r,c+3]
                cust_data.iat[r,4]=cust_data.iat[r,c+4]
# 
                # print ("True",r,c)
##
            elif ((c ==19 and
            cust_data.iloc[r,c-19] == 0 and
            cust_data.iloc[r,c-18] == 0 and
            cust_data.iloc[r,c-17] == 0 and
            cust_data.iloc[r,c-16] == 0 and
            cust_data.iloc[r,c-15] == 0 and
            cust_data.iloc[r,c-14] == 0 and
            cust_data.iloc[r,c-13] == 0 and
            cust_data.iloc[r,c-12] == 0 and
            cust_data.iloc[r,c-11] == 0 and
            cust_data.iloc[r,c-10] == 0 and
            cust_data.iloc[r,c-9] == 0 and
            cust_data.iloc[r,c-8] == 0 and
            cust_data.iloc[r,c-7] == 0 and
            cust_data.iloc[r,c-6] == 0 and
            cust_data.iloc[r,c-5] == 0 and
            cust_data.iloc[r,c-4] == 0 and
            cust_data.iloc[r,c-3] == 0 and
            cust_data.iloc[r,c-2] == 0 and
            cust_data.iloc[r,c-1] == 0 and
            cust_data.iloc[r,c] == 0 and
            cust_data.iloc[r,c+1] > 0 and
            cust_data.iloc[r,c+2] > 0 and
            cust_data.iloc[r,c+3] > 0 and
            cust_data.iloc[r,c+4] > 0 )):
#
                cust_data.iat[r,0]=cust_data.iat[r,c]
                cust_data.iat[r,1]=cust_data.iat[r,c+1]
                cust_data.iat[r,2]=cust_data.iat[r,c+2]
                cust_data.iat[r,3]=cust_data.iat[r,c+3]
                cust_data.iat[r,4]=cust_data.iat[r,c+4]
# 
                # print ("True",r,c)
##
            elif ((c ==20 and
            cust_data.iloc[r,c-20] == 0 and
            cust_data.iloc[r,c-19] == 0 and
            cust_data.iloc[r,c-18] == 0 and
            cust_data.iloc[r,c-17] == 0 and
            cust_data.iloc[r,c-16] == 0 and
            cust_data.iloc[r,c-15] == 0 and
            cust_data.iloc[r,c-14] == 0 and
            cust_data.iloc[r,c-13] == 0 and
            cust_data.iloc[r,c-12] == 0 and
            cust_data.iloc[r,c-11] == 0 and
            cust_data.iloc[r,c-10] == 0 and
            cust_data.iloc[r,c-9] == 0 and
            cust_data.iloc[r,c-8] == 0 and
            cust_data.iloc[r,c-7] == 0 and
            cust_data.iloc[r,c-6] == 0 and
            cust_data.iloc[r,c-5] == 0 and
            cust_data.iloc[r,c-4] == 0 and
            cust_data.iloc[r,c-3] == 0 and
            cust_data.iloc[r,c-2] == 0 and
            cust_data.iloc[r,c-1] == 0 and
            cust_data.iloc[r,c] == 0 and
            cust_data.iloc[r,c+1] > 0 and
            cust_data.iloc[r,c+2] > 0 and
            cust_data.iloc[r,c+3] > 0 and
            cust_data.iloc[r,c+4] > 0 )):
#
                cust_data.iat[r,0]=cust_data.iat[r,c]
                cust_data.iat[r,1]=cust_data.iat[r,c+1]
                cust_data.iat[r,2]=cust_data.iat[r,c+2]
                cust_data.iat[r,3]=cust_data.iat[r,c+3]
                cust_data.iat[r,4]=cust_data.iat[r,c+4]
# 
                # print ("True",r,c)
##
            elif ((c ==21 and
            cust_data.iloc[r,c-21] == 0 and
            cust_data.iloc[r,c-20] == 0 and
            cust_data.iloc[r,c-19] == 0 and
            cust_data.iloc[r,c-18] == 0 and
            cust_data.iloc[r,c-17] == 0 and
            cust_data.iloc[r,c-16] == 0 and
            cust_data.iloc[r,c-15] == 0 and
            cust_data.iloc[r,c-14] == 0 and
            cust_data.iloc[r,c-13] == 0 and
            cust_data.iloc[r,c-12] == 0 and
            cust_data.iloc[r,c-11] == 0 and
            cust_data.iloc[r,c-10] == 0 and
            cust_data.iloc[r,c-9] == 0 and
            cust_data.iloc[r,c-8] == 0 and
            cust_data.iloc[r,c-7] == 0 and
            cust_data.iloc[r,c-6] == 0 and
            cust_data.iloc[r,c-5] == 0 and
            cust_data.iloc[r,c-4] == 0 and
            cust_data.iloc[r,c-3] == 0 and
            cust_data.iloc[r,c-2] == 0 and
            cust_data.iloc[r,c-1] == 0 and
            cust_data.iloc[r,c] == 0 and
            cust_data.iloc[r,c+1] > 0 and
            cust_data.iloc[r,c+2] > 0 and
            cust_data.iloc[r,c+3] > 0 and
            cust_data.iloc[r,c+4] > 0 )):
#
                cust_data.iat[r,0]=cust_data.iat[r,c]
                cust_data.iat[r,1]=cust_data.iat[r,c+1]
                cust_data.iat[r,2]=cust_data.iat[r,c+2]
                cust_data.iat[r,3]=cust_data.iat[r,c+3]
                cust_data.iat[r,4]=cust_data.iat[r,c+4]
# 
                # print ("True",r,c)
##
            elif ((c ==22 and
            cust_data.iloc[r,c-22] == 0 and
            cust_data.iloc[r,c-21] == 0 and
            cust_data.iloc[r,c-20] == 0 and
            cust_data.iloc[r,c-19] == 0 and
            cust_data.iloc[r,c-18] == 0 and
            cust_data.iloc[r,c-17] == 0 and
            cust_data.iloc[r,c-16] == 0 and
            cust_data.iloc[r,c-15] == 0 and
            cust_data.iloc[r,c-14] == 0 and
            cust_data.iloc[r,c-13] == 0 and
            cust_data.iloc[r,c-12] == 0 and
            cust_data.iloc[r,c-11] == 0 and
            cust_data.iloc[r,c-10] == 0 and
            cust_data.iloc[r,c-9] == 0 and
            cust_data.iloc[r,c-8] == 0 and
            cust_data.iloc[r,c-7] == 0 and
            cust_data.iloc[r,c-6] == 0 and
            cust_data.iloc[r,c-5] == 0 and
            cust_data.iloc[r,c-4] == 0 and
            cust_data.iloc[r,c-3] == 0 and
            cust_data.iloc[r,c-2] == 0 and
            cust_data.iloc[r,c-1] == 0 and
            cust_data.iloc[r,c] == 0 and
            cust_data.iloc[r,c+1] > 0 and
            cust_data.iloc[r,c+2] > 0 and
            cust_data.iloc[r,c+3] > 0 and
            cust_data.iloc[r,c+4] > 0 )):
#
                cust_data.iat[r,0]=cust_data.iat[r,c]
                cust_data.iat[r,1]=cust_data.iat[r,c+1]
                cust_data.iat[r,2]=cust_data.iat[r,c+2]
                cust_data.iat[r,3]=cust_data.iat[r,c+3]
                cust_data.iat[r,4]=cust_data.iat[r,c+4]
# 
                # print ("True",r,c)
##
            elif ((c ==23 and
            cust_data.iloc[r,c-23] == 0 and
            cust_data.iloc[r,c-22] == 0 and
            cust_data.iloc[r,c-21] == 0 and
            cust_data.iloc[r,c-20] == 0 and
            cust_data.iloc[r,c-19] == 0 and
            cust_data.iloc[r,c-18] == 0 and
            cust_data.iloc[r,c-17] == 0 and
            cust_data.iloc[r,c-16] == 0 and
            cust_data.iloc[r,c-15] == 0 and
            cust_data.iloc[r,c-14] == 0 and
            cust_data.iloc[r,c-13] == 0 and
            cust_data.iloc[r,c-12] == 0 and
            cust_data.iloc[r,c-11] == 0 and
            cust_data.iloc[r,c-10] == 0 and
            cust_data.iloc[r,c-9] == 0 and
            cust_data.iloc[r,c-8] == 0 and
            cust_data.iloc[r,c-7] == 0 and
            cust_data.iloc[r,c-6] == 0 and
            cust_data.iloc[r,c-5] == 0 and
            cust_data.iloc[r,c-4] == 0 and
            cust_data.iloc[r,c-3] == 0 and
            cust_data.iloc[r,c-2] == 0 and
            cust_data.iloc[r,c-1] == 0 and
            cust_data.iloc[r,c] == 0 and
            cust_data.iloc[r,c+1] > 0 and
            cust_data.iloc[r,c+2] > 0 and
            cust_data.iloc[r,c+3] > 0 and
            cust_data.iloc[r,c+4] > 0 )):
#
                cust_data.iat[r,0]=cust_data.iat[r,c]
                cust_data.iat[r,1]=cust_data.iat[r,c+1]
                cust_data.iat[r,2]=cust_data.iat[r,c+2]
                cust_data.iat[r,3]=cust_data.iat[r,c+3]
                cust_data.iat[r,4]=cust_data.iat[r,c+4]
# 
                # print ("True",r,c)
##
            elif ((c ==24 and
            cust_data.iloc[r,c-24] == 0 and
            cust_data.iloc[r,c-23] == 0 and
            cust_data.iloc[r,c-22] == 0 and
            cust_data.iloc[r,c-21] == 0 and
            cust_data.iloc[r,c-20] == 0 and
            cust_data.iloc[r,c-19] == 0 and
            cust_data.iloc[r,c-18] == 0 and
            cust_data.iloc[r,c-17] == 0 and
            cust_data.iloc[r,c-16] == 0 and
            cust_data.iloc[r,c-15] == 0 and
            cust_data.iloc[r,c-14] == 0 and
            cust_data.iloc[r,c-13] == 0 and
            cust_data.iloc[r,c-12] == 0 and
            cust_data.iloc[r,c-11] == 0 and
            cust_data.iloc[r,c-10] == 0 and
            cust_data.iloc[r,c-9] == 0 and
            cust_data.iloc[r,c-8] == 0 and
            cust_data.iloc[r,c-7] == 0 and
            cust_data.iloc[r,c-6] == 0 and
            cust_data.iloc[r,c-5] == 0 and
            cust_data.iloc[r,c-4] == 0 and
            cust_data.iloc[r,c-3] == 0 and
            cust_data.iloc[r,c-2] == 0 and
            cust_data.iloc[r,c-1] == 0 and
            cust_data.iloc[r,c] == 0 and
            cust_data.iloc[r,c+1] > 0 and
            cust_data.iloc[r,c+2] > 0 and
            cust_data.iloc[r,c+3] > 0 and
            cust_data.iloc[r,c+4] > 0 )):
#
                cust_data.iat[r,0]=cust_data.iat[r,c]
                cust_data.iat[r,1]=cust_data.iat[r,c+1]
                cust_data.iat[r,2]=cust_data.iat[r,c+2]
                cust_data.iat[r,3]=cust_data.iat[r,c+3]
                cust_data.iat[r,4]=cust_data.iat[r,c+4]
# 
                # print ("True",r,c)
##
            elif ((c ==25 and
            cust_data.iloc[r,c-25] == 0 and
            cust_data.iloc[r,c-24] == 0 and
            cust_data.iloc[r,c-23] == 0 and
            cust_data.iloc[r,c-22] == 0 and
            cust_data.iloc[r,c-21] == 0 and
            cust_data.iloc[r,c-20] == 0 and
            cust_data.iloc[r,c-19] == 0 and
            cust_data.iloc[r,c-18] == 0 and
            cust_data.iloc[r,c-17] == 0 and
            cust_data.iloc[r,c-16] == 0 and
            cust_data.iloc[r,c-15] == 0 and
            cust_data.iloc[r,c-14] == 0 and
            cust_data.iloc[r,c-13] == 0 and
            cust_data.iloc[r,c-12] == 0 and
            cust_data.iloc[r,c-11] == 0 and
            cust_data.iloc[r,c-10] == 0 and
            cust_data.iloc[r,c-9] == 0 and
            cust_data.iloc[r,c-8] == 0 and
            cust_data.iloc[r,c-7] == 0 and
            cust_data.iloc[r,c-6] == 0 and
            cust_data.iloc[r,c-5] == 0 and
            cust_data.iloc[r,c-4] == 0 and
            cust_data.iloc[r,c-3] == 0 and
            cust_data.iloc[r,c-2] == 0 and
            cust_data.iloc[r,c-1] == 0 and
            cust_data.iloc[r,c] == 0 and
            cust_data.iloc[r,c+1] > 0 and
            cust_data.iloc[r,c+2] > 0 and
            cust_data.iloc[r,c+3] > 0 and
            cust_data.iloc[r,c+4] > 0 )):
#
                cust_data.iat[r,0]=cust_data.iat[r,c]
                cust_data.iat[r,1]=cust_data.iat[r,c+1]
                cust_data.iat[r,2]=cust_data.iat[r,c+2]
                cust_data.iat[r,3]=cust_data.iat[r,c+3]
                cust_data.iat[r,4]=cust_data.iat[r,c+4]
# 
                # print ("True",r,c)
##
            elif ((c ==26 and
            cust_data.iloc[r,c-26] == 0 and
            cust_data.iloc[r,c-25] == 0 and
            cust_data.iloc[r,c-24] == 0 and
            cust_data.iloc[r,c-23] == 0 and
            cust_data.iloc[r,c-22] == 0 and
            cust_data.iloc[r,c-21] == 0 and
            cust_data.iloc[r,c-20] == 0 and
            cust_data.iloc[r,c-19] == 0 and
            cust_data.iloc[r,c-18] == 0 and
            cust_data.iloc[r,c-17] == 0 and
            cust_data.iloc[r,c-16] == 0 and
            cust_data.iloc[r,c-15] == 0 and
            cust_data.iloc[r,c-14] == 0 and
            cust_data.iloc[r,c-13] == 0 and
            cust_data.iloc[r,c-12] == 0 and
            cust_data.iloc[r,c-11] == 0 and
            cust_data.iloc[r,c-10] == 0 and
            cust_data.iloc[r,c-9] == 0 and
            cust_data.iloc[r,c-8] == 0 and
            cust_data.iloc[r,c-7] == 0 and
            cust_data.iloc[r,c-6] == 0 and
            cust_data.iloc[r,c-5] == 0 and
            cust_data.iloc[r,c-4] == 0 and
            cust_data.iloc[r,c-3] == 0 and
            cust_data.iloc[r,c-2] == 0 and
            cust_data.iloc[r,c-1] == 0 and
            cust_data.iloc[r,c] == 0 and
            cust_data.iloc[r,c+1] > 0 and
            cust_data.iloc[r,c+2] > 0 and
            cust_data.iloc[r,c+3] > 0 and
            cust_data.iloc[r,c+4] > 0 )):
#
                cust_data.iat[r,0]=cust_data.iat[r,c]
                cust_data.iat[r,1]=cust_data.iat[r,c+1]
                cust_data.iat[r,2]=cust_data.iat[r,c+2]
                cust_data.iat[r,3]=cust_data.iat[r,c+3]
                cust_data.iat[r,4]=cust_data.iat[r,c+4]
# 
                # print ("True",r,c)
##
            elif ((c ==27 and
            cust_data.iloc[r,c-27] == 0 and
            cust_data.iloc[r,c-26] == 0 and
            cust_data.iloc[r,c-25] == 0 and
            cust_data.iloc[r,c-24] == 0 and
            cust_data.iloc[r,c-23] == 0 and
            cust_data.iloc[r,c-22] == 0 and
            cust_data.iloc[r,c-21] == 0 and
            cust_data.iloc[r,c-20] == 0 and
            cust_data.iloc[r,c-19] == 0 and
            cust_data.iloc[r,c-18] == 0 and
            cust_data.iloc[r,c-17] == 0 and
            cust_data.iloc[r,c-16] == 0 and
            cust_data.iloc[r,c-15] == 0 and
            cust_data.iloc[r,c-14] == 0 and
            cust_data.iloc[r,c-13] == 0 and
            cust_data.iloc[r,c-12] == 0 and
            cust_data.iloc[r,c-11] == 0 and
            cust_data.iloc[r,c-10] == 0 and
            cust_data.iloc[r,c-9] == 0 and
            cust_data.iloc[r,c-8] == 0 and
            cust_data.iloc[r,c-7] == 0 and
            cust_data.iloc[r,c-6] == 0 and
            cust_data.iloc[r,c-5] == 0 and
            cust_data.iloc[r,c-4] == 0 and
            cust_data.iloc[r,c-3] == 0 and
            cust_data.iloc[r,c-2] == 0 and
            cust_data.iloc[r,c-1] == 0 and
            cust_data.iloc[r,c] == 0 and
            cust_data.iloc[r,c+1] > 0 and
            cust_data.iloc[r,c+2] > 0 and
            cust_data.iloc[r,c+3] > 0 and
            cust_data.iloc[r,c+4] > 0 )):
#
                cust_data.iat[r,0]=cust_data.iat[r,c]
                cust_data.iat[r,1]=cust_data.iat[r,c+1]
                cust_data.iat[r,2]=cust_data.iat[r,c+2]
                cust_data.iat[r,3]=cust_data.iat[r,c+3]
                cust_data.iat[r,4]=cust_data.iat[r,c+4]
# 
                # print ("True",r,c)
##
            elif ((c ==28 and
            cust_data.iloc[r,c-28] == 0 and
            cust_data.iloc[r,c-27] == 0 and
            cust_data.iloc[r,c-26] == 0 and
            cust_data.iloc[r,c-25] == 0 and
            cust_data.iloc[r,c-24] == 0 and
            cust_data.iloc[r,c-23] == 0 and
            cust_data.iloc[r,c-22] == 0 and
            cust_data.iloc[r,c-21] == 0 and
            cust_data.iloc[r,c-20] == 0 and
            cust_data.iloc[r,c-19] == 0 and
            cust_data.iloc[r,c-18] == 0 and
            cust_data.iloc[r,c-17] == 0 and
            cust_data.iloc[r,c-16] == 0 and
            cust_data.iloc[r,c-15] == 0 and
            cust_data.iloc[r,c-14] == 0 and
            cust_data.iloc[r,c-13] == 0 and
            cust_data.iloc[r,c-12] == 0 and
            cust_data.iloc[r,c-11] == 0 and
            cust_data.iloc[r,c-10] == 0 and
            cust_data.iloc[r,c-9] == 0 and
            cust_data.iloc[r,c-8] == 0 and
            cust_data.iloc[r,c-7] == 0 and
            cust_data.iloc[r,c-6] == 0 and
            cust_data.iloc[r,c-5] == 0 and
            cust_data.iloc[r,c-4] == 0 and
            cust_data.iloc[r,c-3] == 0 and
            cust_data.iloc[r,c-2] == 0 and
            cust_data.iloc[r,c-1] == 0 and
            cust_data.iloc[r,c] == 0 and
            cust_data.iloc[r,c+1] > 0 and
            cust_data.iloc[r,c+2] > 0 and
            cust_data.iloc[r,c+3] > 0 and
            cust_data.iloc[r,c+4] > 0 )):
#
                cust_data.iat[r,0]=cust_data.iat[r,c]
                cust_data.iat[r,1]=cust_data.iat[r,c+1]
                cust_data.iat[r,2]=cust_data.iat[r,c+2]
                cust_data.iat[r,3]=cust_data.iat[r,c+3]
                cust_data.iat[r,4]=cust_data.iat[r,c+4]
# 
                # print ("True",r,c)
##
            elif ((c ==29 and
            cust_data.iloc[r,c-29] == 0 and
            cust_data.iloc[r,c-28] == 0 and
            cust_data.iloc[r,c-27] == 0 and
            cust_data.iloc[r,c-26] == 0 and
            cust_data.iloc[r,c-25] == 0 and
            cust_data.iloc[r,c-24] == 0 and
            cust_data.iloc[r,c-23] == 0 and
            cust_data.iloc[r,c-22] == 0 and
            cust_data.iloc[r,c-21] == 0 and
            cust_data.iloc[r,c-20] == 0 and
            cust_data.iloc[r,c-19] == 0 and
            cust_data.iloc[r,c-18] == 0 and
            cust_data.iloc[r,c-17] == 0 and
            cust_data.iloc[r,c-16] == 0 and
            cust_data.iloc[r,c-15] == 0 and
            cust_data.iloc[r,c-14] == 0 and
            cust_data.iloc[r,c-13] == 0 and
            cust_data.iloc[r,c-12] == 0 and
            cust_data.iloc[r,c-11] == 0 and
            cust_data.iloc[r,c-10] == 0 and
            cust_data.iloc[r,c-9] == 0 and
            cust_data.iloc[r,c-8] == 0 and
            cust_data.iloc[r,c-7] == 0 and
            cust_data.iloc[r,c-6] == 0 and
            cust_data.iloc[r,c-5] == 0 and
            cust_data.iloc[r,c-4] == 0 and
            cust_data.iloc[r,c-3] == 0 and
            cust_data.iloc[r,c-2] == 0 and
            cust_data.iloc[r,c-1] == 0 and
            cust_data.iloc[r,c] == 0 and
            cust_data.iloc[r,c+1] > 0 and
            cust_data.iloc[r,c+2] > 0 and
            cust_data.iloc[r,c+3] > 0 and
            cust_data.iloc[r,c+4] > 0 )):
#
                cust_data.iat[r,0]=cust_data.iat[r,c]
                cust_data.iat[r,1]=cust_data.iat[r,c+1]
                cust_data.iat[r,2]=cust_data.iat[r,c+2]
                cust_data.iat[r,3]=cust_data.iat[r,c+3]
                cust_data.iat[r,4]=cust_data.iat[r,c+4]
# 
                # print ("True",r,c)
##
            elif ((c ==30 and
            cust_data.iloc[r,c-30] == 0 and
            cust_data.iloc[r,c-29] == 0 and
            cust_data.iloc[r,c-28] == 0 and
            cust_data.iloc[r,c-27] == 0 and
            cust_data.iloc[r,c-26] == 0 and
            cust_data.iloc[r,c-25] == 0 and
            cust_data.iloc[r,c-24] == 0 and
            cust_data.iloc[r,c-23] == 0 and
            cust_data.iloc[r,c-22] == 0 and
            cust_data.iloc[r,c-21] == 0 and
            cust_data.iloc[r,c-20] == 0 and
            cust_data.iloc[r,c-19] == 0 and
            cust_data.iloc[r,c-18] == 0 and
            cust_data.iloc[r,c-17] == 0 and
            cust_data.iloc[r,c-16] == 0 and
            cust_data.iloc[r,c-15] == 0 and
            cust_data.iloc[r,c-14] == 0 and
            cust_data.iloc[r,c-13] == 0 and
            cust_data.iloc[r,c-12] == 0 and
            cust_data.iloc[r,c-11] == 0 and
            cust_data.iloc[r,c-10] == 0 and
            cust_data.iloc[r,c-9] == 0 and
            cust_data.iloc[r,c-8] == 0 and
            cust_data.iloc[r,c-7] == 0 and
            cust_data.iloc[r,c-6] == 0 and
            cust_data.iloc[r,c-5] == 0 and
            cust_data.iloc[r,c-4] == 0 and
            cust_data.iloc[r,c-3] == 0 and
            cust_data.iloc[r,c-2] == 0 and
            cust_data.iloc[r,c-1] == 0 and
            cust_data.iloc[r,c] == 0 and
            cust_data.iloc[r,c+1] > 0 and
            cust_data.iloc[r,c+2] > 0 and
            cust_data.iloc[r,c+3] > 0 and
            cust_data.iloc[r,c+4] > 0 )):
#
                cust_data.iat[r,0]=cust_data.iat[r,c]
                cust_data.iat[r,1]=cust_data.iat[r,c+1]
                cust_data.iat[r,2]=cust_data.iat[r,c+2]
                cust_data.iat[r,3]=cust_data.iat[r,c+3]
                cust_data.iat[r,4]=cust_data.iat[r,c+4]
# 
                # print ("True",r,c)
##
            elif ((c ==31 and
            cust_data.iloc[r,c-31] == 0 and
            cust_data.iloc[r,c-30] == 0 and
            cust_data.iloc[r,c-29] == 0 and
            cust_data.iloc[r,c-28] == 0 and
            cust_data.iloc[r,c-27] == 0 and
            cust_data.iloc[r,c-26] == 0 and
            cust_data.iloc[r,c-25] == 0 and
            cust_data.iloc[r,c-24] == 0 and
            cust_data.iloc[r,c-23] == 0 and
            cust_data.iloc[r,c-22] == 0 and
            cust_data.iloc[r,c-21] == 0 and
            cust_data.iloc[r,c-20] == 0 and
            cust_data.iloc[r,c-19] == 0 and
            cust_data.iloc[r,c-18] == 0 and
            cust_data.iloc[r,c-17] == 0 and
            cust_data.iloc[r,c-16] == 0 and
            cust_data.iloc[r,c-15] == 0 and
            cust_data.iloc[r,c-14] == 0 and
            cust_data.iloc[r,c-13] == 0 and
            cust_data.iloc[r,c-12] == 0 and
            cust_data.iloc[r,c-11] == 0 and
            cust_data.iloc[r,c-10] == 0 and
            cust_data.iloc[r,c-9] == 0 and
            cust_data.iloc[r,c-8] == 0 and
            cust_data.iloc[r,c-7] == 0 and
            cust_data.iloc[r,c-6] == 0 and
            cust_data.iloc[r,c-5] == 0 and
            cust_data.iloc[r,c-4] == 0 and
            cust_data.iloc[r,c-3] == 0 and
            cust_data.iloc[r,c-2] == 0 and
            cust_data.iloc[r,c-1] == 0 and
            cust_data.iloc[r,c] == 0 and
            cust_data.iloc[r,c+1] > 0 and
            cust_data.iloc[r,c+2] > 0 and
            cust_data.iloc[r,c+3] > 0 and
            cust_data.iloc[r,c+4] > 0 )):
#
                cust_data.iat[r,0]=cust_data.iat[r,c]
                cust_data.iat[r,1]=cust_data.iat[r,c+1]
                cust_data.iat[r,2]=cust_data.iat[r,c+2]
                cust_data.iat[r,3]=cust_data.iat[r,c+3]
                cust_data.iat[r,4]=cust_data.iat[r,c+4]
# 
                # print ("True",r,c)
##
            elif ((c ==32 and
            cust_data.iloc[r,c-32] == 0 and
            cust_data.iloc[r,c-31] == 0 and
            cust_data.iloc[r,c-30] == 0 and
            cust_data.iloc[r,c-29] == 0 and
            cust_data.iloc[r,c-28] == 0 and
            cust_data.iloc[r,c-27] == 0 and
            cust_data.iloc[r,c-26] == 0 and
            cust_data.iloc[r,c-25] == 0 and
            cust_data.iloc[r,c-24] == 0 and
            cust_data.iloc[r,c-23] == 0 and
            cust_data.iloc[r,c-22] == 0 and
            cust_data.iloc[r,c-21] == 0 and
            cust_data.iloc[r,c-20] == 0 and
            cust_data.iloc[r,c-19] == 0 and
            cust_data.iloc[r,c-18] == 0 and
            cust_data.iloc[r,c-17] == 0 and
            cust_data.iloc[r,c-16] == 0 and
            cust_data.iloc[r,c-15] == 0 and
            cust_data.iloc[r,c-14] == 0 and
            cust_data.iloc[r,c-13] == 0 and
            cust_data.iloc[r,c-12] == 0 and
            cust_data.iloc[r,c-11] == 0 and
            cust_data.iloc[r,c-10] == 0 and
            cust_data.iloc[r,c-9] == 0 and
            cust_data.iloc[r,c-8] == 0 and
            cust_data.iloc[r,c-7] == 0 and
            cust_data.iloc[r,c-6] == 0 and
            cust_data.iloc[r,c-5] == 0 and
            cust_data.iloc[r,c-4] == 0 and
            cust_data.iloc[r,c-3] == 0 and
            cust_data.iloc[r,c-2] == 0 and
            cust_data.iloc[r,c-1] == 0 and
            cust_data.iloc[r,c] == 0 and
            cust_data.iloc[r,c+1] > 0 and
            cust_data.iloc[r,c+2] > 0 and
            cust_data.iloc[r,c+3] > 0 and
            cust_data.iloc[r,c+4] > 0 )):
#
                cust_data.iat[r,0] = cust_data.iat[r,c]
                cust_data.iat[r,1] = cust_data.iat[r,c+1]
                cust_data.iat[r,2] = cust_data.iat[r,c+2]
                cust_data.iat[r,3] = cust_data.iat[r,c+3]
                cust_data.iat[r,4] = cust_data.iat[r,c+4]
# 
                # print ("True",r,c)
##
            elif ((c ==33 and
            cust_data.iloc[r,c-33] == 0 and
            cust_data.iloc[r,c-32] == 0 and
            cust_data.iloc[r,c-31] == 0 and
            cust_data.iloc[r,c-30] == 0 and
            cust_data.iloc[r,c-29] == 0 and
            cust_data.iloc[r,c-28] == 0 and
            cust_data.iloc[r,c-27] == 0 and
            cust_data.iloc[r,c-26] == 0 and
            cust_data.iloc[r,c-25] == 0 and
            cust_data.iloc[r,c-24] == 0 and
            cust_data.iloc[r,c-23] == 0 and
            cust_data.iloc[r,c-22] == 0 and
            cust_data.iloc[r,c-21] == 0 and
            cust_data.iloc[r,c-20] == 0 and
            cust_data.iloc[r,c-19] == 0 and
            cust_data.iloc[r,c-18] == 0 and
            cust_data.iloc[r,c-17] == 0 and
            cust_data.iloc[r,c-16] == 0 and
            cust_data.iloc[r,c-15] == 0 and
            cust_data.iloc[r,c-14] == 0 and
            cust_data.iloc[r,c-13] == 0 and
            cust_data.iloc[r,c-12] == 0 and
            cust_data.iloc[r,c-11] == 0 and
            cust_data.iloc[r,c-10] == 0 and
            cust_data.iloc[r,c-9] == 0 and
            cust_data.iloc[r,c-8] == 0 and
            cust_data.iloc[r,c-7] == 0 and
            cust_data.iloc[r,c-6] == 0 and
            cust_data.iloc[r,c-5] == 0 and
            cust_data.iloc[r,c-4] == 0 and
            cust_data.iloc[r,c-3] == 0 and
            cust_data.iloc[r,c-2] == 0 and
            cust_data.iloc[r,c-1] == 0 and
            cust_data.iloc[r,c] == 0 and
            cust_data.iloc[r,c+1] > 0 and
            cust_data.iloc[r,c+2] > 0 and
            cust_data.iloc[r,c+3] > 0 and
            cust_data.iloc[r,c+4] > 0 )):
#
                cust_data.iat[r,0]=cust_data.iat[r,c]
                cust_data.iat[r,1]=cust_data.iat[r,c+1]
                cust_data.iat[r,2]=cust_data.iat[r,c+2]
                cust_data.iat[r,3]=cust_data.iat[r,c+3]
                cust_data.iat[r,4]=cust_data.iat[r,c+4]
# 
        #        # print ("True",r,c)
##

# %%
cust_data.head(10)

# %% [markdown]
# ### Remove all rows not starting with 0 and P1 - P4 >0

# %%
cust_data = cust_data[(cust_data.P1 < 1) & (cust_data.P2 > 0) & (cust_data.P3 > 0)]

# %% [markdown]
# ### Keep only the first 5 cols

# %%
cust_data.drop(cust_data.iloc[:, 5:38], inplace = True, axis = 1)

# %%
cust_data.head()

# %%
cust_data.describe()

# %%
x = cust_data.iloc[:,1:].values

# %%
x[:5]

# %%
y = cust_data.iloc[:, 0].values

# %%
y[:5]

# %%
# split dataset into test/train
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1, test_size=0.3)

# %%
# binary classifier
#from sklearn.linear_model import LogisticRegression
#log_reg = LogisticRegression()
#log_reg.fit(X_train, y_train)
#log_reg.score(X_test, y_test)

# %%
from sklearn.svm import SVC
svm = SVC()
svm.fit(X_train, y_train)
svm.score(X_test, y_test)
